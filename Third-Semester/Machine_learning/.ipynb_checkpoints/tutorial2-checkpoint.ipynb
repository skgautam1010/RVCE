# %%
import matplotlib.pyplot as plt

# %%
plt.plot([1,2,3,4])

# %%
plt.plot([1,2,3,4],[5,3,8,6],'g--')
plt.ylabel('sample data')
plt.xlabel('data of x')
# Out:
# Text(0.5, 0, 'data of x')

# %%
import numpy as np

# %%
x=np.arange(0.0,6,0.4)

# %%
x
plt.plot(x,x**2,'r-',x,x**3,'b:',x,x*2,'c^')

# %%
plt.boxplot(x)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f973e3b8580>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f973e3b8c40>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f973e3b8220>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f973e3c1340>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f973e3c1640>],
#  'means': []}

# %%
import pandas as pd
df=pd.read_csv('ratings.csv')

# %%
new_df=df['rating']

# %%
new_df.head()
# Out:
# 0    4.0
# 1    4.0
# 2    4.0
# 3    5.0
# 4    5.0
# Name: rating, dtype: float64

# %%
plt.plot(new_df)

# %%
plt.boxplot(new_df)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f973759e280>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f973759e940>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f9737590ee0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f97375a8040>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f97375a8340>],
#  'means': []}
